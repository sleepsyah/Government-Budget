# %% [markdown]
# <a href="https://colab.research.google.com/github/sleepsyah/Government-Budget/blob/main/Edited_Government_Budget_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Setup
import kagglehub
import os
import pandas as pd
from kagglehub import KaggleDatasetAdapter

#health data
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/government budget project/Health.xlsx'
df_health = pd.read_excel(file_path)

#graduation rate data (not used)
# file_path2 = '/content/drive/MyDrive/government budget project/grad_rates.xlsx'
# df_grad = pd.read_excel(file_path2)
# df_grad = df_grad.drop(df_grad.index[:10])
# #print(df_grad)

# #life expectancy data (SE is standard error) not used
# file_path3 = '/content/drive/MyDrive/government budget project/life_expectancy2020.csv'
# df_LE2020 = pd.read_csv(file_path3)

# file_path4 = '/content/drive/MyDrive/government budget project/life_expectancy2019.csv'
# df_LE2019 = pd.read_csv(file_path4)

# file_path5 = '/content/drive/MyDrive/government budget project/life_expectancy2018.csv'
# df_LE2018 = pd.read_csv(file_path5)

#unemployment data
file_path30 = "/Unemployment in America Per US State.csv"

# Load the latest version
df_unemployed = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "justin2028/unemployment-in-america-per-us-state",
  file_path30,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)


# crime data
file_path6 = '/content/drive/MyDrive/government budget project/crime2019.xlsx'
df_crime2019 = pd.read_excel(file_path6, header=3)

file_path7 = '/content/drive/MyDrive/government budget project/crime2018.xlsx'
df_crime2018 = pd.read_excel(file_path7, header =3)

file_path8 = '/content/drive/MyDrive/government budget project/crime2017.xlsx'
df_crime2017 = pd.read_excel(file_path8, header = 3)

file_path15 = '/content/drive/MyDrive/government budget project/crime2016.xlsx'
df_crime2016 = pd.read_excel(file_path15, header = 3)

file_path16 = '/content/drive/MyDrive/government budget project/crime2015.xlsx'
df_crime2015 = pd.read_excel(file_path16, header = 3)

file_path49 = '/content/drive/MyDrive/government budget project/crime2014.xlsx'
df_crime2014 = pd.read_excel(file_path49, header = 3)

file_path48 = '/content/drive/MyDrive/government budget project/crime2013.xlsx'
df_crime2013 = pd.read_excel(file_path48, header = 3)


#spending by state
file_path9 = '/content/drive/MyDrive/government budget project/government_spending.csv'
df_govspending= pd.read_csv(file_path9,header=2,skipfooter=5)


#college enrollment data
file_path60 = '/content/drive/MyDrive/government budget project/college_enrollment2013.xlsx'
file_path61 = '/content/drive/MyDrive/government budget project/college_enrollment2014.xlsx'
file_path17 = '/content/drive/MyDrive/government budget project/college_enrollment2015.xlsx'
file_path18 = '/content/drive/MyDrive/government budget project/college_enrollment2016.xlsx'
file_path11 = '/content/drive/MyDrive/government budget project/college_enrollment2017.xlsx'
file_path12 = '/content/drive/MyDrive/government budget project/college_enrollment2018.xlsx'
file_path13 = '/content/drive/MyDrive/government budget project/college_enrollment2019.xlsx'

df_college2013 = pd.read_excel(file_path60,header=2)
df_college2014 = pd.read_excel(file_path61,header=2)
df_college2015 = pd.read_excel(file_path17,header=2)
df_college2016 = pd.read_excel(file_path18,header=2)
df_college2017 = pd.read_excel(file_path11,header=2)
df_college2018 = pd.read_excel(file_path12,header=2)
df_college2019 = pd.read_excel(file_path13,header=2)

# sat file download
path = kagglehub.dataset_download("zakarii/sat-act-files")

print("Path to dataset files:", path)

for item in os.listdir(path):
  print(item)

df_sat2017 = pd.read_csv(path + "/sat_2017.csv")
df_sat2018 = pd.read_csv(path + "/sat_2018.csv")
df_sat2019 = pd.read_csv(path + "/sat_2019.csv",encoding = "latin1")
file_path14 = '/content/drive/MyDrive/government budget project/sat15-16.xlsx'
df_sat2015_2016 = pd.read_excel(file_path14,header=1)
file_path32 = '/content/drive/MyDrive/government budget project/sat2011.xlsm'
file_path33 = '/content/drive/MyDrive/government budget project/sat2012.xlsx'
file_path34 = '/content/drive/MyDrive/government budget project/sat2013.xlsx'
file_path35 = '/content/drive/MyDrive/government budget project/sat2014.xlsx'
df_sat2013 = pd.read_excel(file_path34,header=1)
df_sat2014 = pd.read_excel(file_path35,header=1)


path2 = kagglehub.dataset_download("marshuu/poverty-estimates")
print("Path to dataset files:", path2)
for item in os.listdir(path2):
  print(item)
df_poverty = pd.read_csv(path2 + "/poverty.csv")

# infant mortality download
file_path19 = '/content/drive/MyDrive/government budget project/infant_mortality.xlsx'
df_infantmort = pd.read_excel(file_path19)


#health insurance download

file_path44 = '/content/drive/MyDrive/government budget project/healthinsurance2013.csv'
df_insur2013 = pd.read_csv(file_path44, header=2)

file_path45 = '/content/drive/MyDrive/government budget project/healthinsurance2014.csv'
df_insur2014 = pd.read_csv(file_path45, header=2)

file_path20 = '/content/drive/MyDrive/government budget project/healthinsurance2015.csv'
df_insur2015 = pd.read_csv(file_path20, header=2)

file_path21 = '/content/drive/MyDrive/government budget project/healthinsurance2016.csv'
df_insur2016 = pd.read_csv(file_path21, header=2)

file_path22 = '/content/drive/MyDrive/government budget project/healthinsurance2017.csv'
df_insur2017 = pd.read_csv(file_path22, header=2)

file_path23 = '/content/drive/MyDrive/government budget project/healthinsurance2018.csv'
df_insur2018 = pd.read_csv(file_path23, header=2)

file_path24 = '/content/drive/MyDrive/government budget project/healthinsurance2019.csv'
df_insur2019 = pd.read_csv(file_path24, header=2)

#high school grad rate
file_path25 = '/content/drive/MyDrive/government budget project/highschool_grad_rates.xlsx'
df_highgradrate = pd.read_excel(file_path25)


#act

file_path39 = '/content/drive/MyDrive/government budget project/act2013.xlsx'
file_path40 = '/content/drive/MyDrive/government budget project/act2014.xlsx'
file_path26 = '/content/drive/MyDrive/government budget project/act2015.xlsx'
file_path27 = '/content/drive/MyDrive/government budget project/act2016.xlsx'

df_act2013 = pd.read_excel(file_path39)
df_act2014 = pd.read_excel(file_path40)
df_act2015 = pd.read_excel(file_path26)
df_act2016 = pd.read_excel(file_path27)
df_act2017 = pd.read_csv(path + "/act_2017.csv", header=0)
df_act2018 = pd.read_csv(path + "/act_2018.csv")
df_act2019 = pd.read_csv(path + "/act_2019.csv")

print(df_govspending.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /tmp/ipykernel_275/3095553227.py:34: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df_unemployed = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'unemployment-in-america-per-us-state' dataset.
# /tmp/ipykernel_275/3095553227.py:70: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df_govspending= pd.read_csv(file_path9,header=2,skipfooter=5)
# ...
# 100%|██████████| 5.25k/5.25k [00:00<00:00, 2.77MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/zakarii/sat-act-files/versions/1
# act_2019.csv
# sat_2018.csv
# sat_2017.csv
# sat_2019.csv
# act_2017.csv
# act_2018.csv
# ...

# %%
#@title editing datasets

# Final dataset titles of each are df_sat, df_healthf, df_unemployed2, and df_crimetotals


states = [
    'Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware',
    'Florida','Georgia','Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky',
    'Louisiana','Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi',
    'Missouri','Montana','Nebraska','Nevada','New Hampshire','New Jersey','New Mexico',
    'New York','North Carolina','North Dakota','Ohio','Oklahoma','Oregon','Pennsylvania',
    'Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont',
    'Virginia','Washington','West Virginia','Wisconsin','Wyoming'
]

def clean_df(df,col):
  df=df.copy()
  df[col] = (
        df[col]
        .astype(str)
        .str.replace("%", "", regex=False)
        .str.replace(",", "", regex=False)
        .str.replace(r"\.+$", "", regex=True)
        .str.strip()
  )
  return df


#concat sat data
def clean_sat(df):
  df=df.copy()
  if 'Critical reading score' in df.columns and 'Writing score' in df.columns:
    df["Evidence-Based Reading and Writing"] = (df["Critical reading score"]+df["Writing score"])/2
    df=df.rename(columns={"Math score": "Math"})
    df=df[["State","Year","Math","Participation","Evidence-Based Reading and Writing"]]
    df["Total"]=(df["Evidence-Based Reading and Writing"]+df["Math"])
  return df
df_sat2015_2016=clean_df(df_sat2015_2016,"State")
df_sat2015_2016=clean_sat(df_sat2015_2016)
df_sat2014=clean_df(df_sat2014,"State")
df_sat2014=clean_sat(df_sat2014)
df_sat2013=clean_df(df_sat2013,"State")
df_sat2013=clean_sat(df_sat2013)


df_sat2017["Year"] = 2017
df_sat2018["Year"] = 2018
df_sat2019["Year"] = 2019
df_sat2019a = df_sat2019.drop([39,47])
df_sat2019a = df_sat2019a.rename(columns={"Participation Rate": "Participation"})
df_sat2019a = df_sat2019a.rename(columns={"EBRW": "Evidence-Based Reading and Writing"})

df_sata = pd.concat([df_sat2013,df_sat2014,df_sat2015_2016,df_sat2017, df_sat2018,df_sat2019a],ignore_index=True)
df_sata = df_sata[df_sata['State'].isin(states)]
df_sata["Participation"] = df_sata["Participation"].astype(str).str.replace('%', '', regex=False).astype(float)
df_sat = df_sata[["State","Year", "Participation","Evidence-Based Reading and Writing", "Math","Total"]]

#act dataset fixing
df_act2013["Year"] = 2013
df_act2013['Composite'] = pd.to_numeric(df_act2013['Composite'], errors='coerce')
df_act2014["Year"] = 2014
df_act2014['Composite'] = pd.to_numeric(df_act2014['Composite'], errors='coerce')
df_act2015["Year"] = 2015
df_act2016["Year"] = 2016
df_act2017["Year"] = 2017
df_act2017['Composite'] = df_act2017['Composite'].astype(str).str.replace(r'[^0-9.]', '', regex=True)
df_act2017['Composite'] = pd.to_numeric(df_act2017['Composite'], errors='coerce') # theres a 20.2x value for wyoming
df_act2018["Year"] = 2018
df_act2018a=df_act2018.drop(df_act2018.index[20])
df_act2019["Year"] = 2019
#df_act2017 = df_act2017[df_act2017['State'].isin(states)]

df_acta= pd.concat([df_act2017,df_act2018a,df_act2019],ignore_index=True)
df_actb=df_acta[["Year","State","Composite","Participation"]]
df_actc = pd.concat([df_act2013,df_act2014,df_act2015,df_act2016,df_actb],ignore_index=True)

df_actd = clean_df(df_actc,"State")
df_acte = df_actd[df_actd['State'].isin(states)]
df_acte = df_acte.rename(columns={"Participation": "Participation ACT"})
df_acte["Participation ACT"] = df_acte["Participation ACT"].astype(str).str.replace('%', '', regex=False).astype(float)
df_act = df_acte[["State","Year", "Participation ACT","Composite"]]

#remapping health dataset
state_mapping = { 'AL': 'Alabama', 'AK': 'Alaska', 'AZ': 'Arizona', 'AR': 'Arkansas', 'CA': 'California', 'CO': 'Colorado', 'CT': 'Connecticut', 'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia', 'HI': 'Hawaii', 'ID': 'Idaho', 'IL': 'Illinois', 'IN': 'Indiana', 'IA': 'Iowa', 'KS': 'Kansas', 'KY': 'Kentucky', 'LA': 'Louisiana', 'ME': 'Maine', 'MD': 'Maryland', 'MA': 'Massachusetts', 'MI': 'Michigan', 'MN': 'Minnesota', 'MS': 'Mississippi', 'MO': 'Missouri', 'MT': 'Montana', 'NE': 'Nebraska', 'NV': 'Nevada', 'NH': 'New Hampshire', 'NJ': 'New Jersey', 'NM': 'New Mexico', 'NY': 'New York', 'NC': 'North Carolina', 'ND': 'North Dakota', 'OH': 'Ohio', 'OK': 'Oklahoma', 'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island', 'SC': 'South Carolina', 'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VT': 'Vermont', 'VA': 'Virginia', 'WA': 'Washington', 'WV': 'West Virginia', 'WI': 'Wisconsin', 'WY': 'Wyoming' }
df_health['State'] = df_health['STATE'].map(state_mapping)

#health dataset goes from 2000 to 2023, keeping only 2013-2019
df_health = df_health[df_health['YEAR'] >= 2013]
df_health = df_health[df_health['YEAR'] <= 2019]
df_healtha = df_health[df_health['State'].isin(states)]
df_healthf = df_healtha[['YEAR',"RATIO","State"]]
df_healthf = df_healthf.rename(columns={"YEAR": "Year"}) #Change to "Year" so it is the same name when merging

#unemplyment goes from 1976 to 2022, keeping 2013-2019
df_unemployed1 = df_unemployed[df_unemployed['Year'] >= 2013]
df_unemployed2 = df_unemployed1[df_unemployed1['Year'] <= 2019]
df_unemployed2["Percent (%) of Labor Force Unemployed in State/Area"] = pd.to_numeric(
    df_unemployed2["Percent (%) of Labor Force Unemployed in State/Area"].astype(str).str.replace("%", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.strip(),
    errors="coerce"
)
df_unemployed2=df_unemployed2.rename(columns={'State/Area': "State"})
df_unemployed2=df_unemployed2.rename(columns={"Percent (%) of Labor Force Unemployed in State/Area": "Percent of Labor Force Unemployed in State"})

df_unemployed2 = df_unemployed2[["State", "Year", "Percent of Labor Force Unemployed in State"]]
df_unemployed2 = df_unemployed2.groupby(['State', 'Year']).mean().reset_index()
df_unemployed2 = df_unemployed2.sort_values(by=['Year', 'State']).reset_index(drop=True)

# Keep only rows where 'State' is in this list
df_unemployed2 = df_unemployed2[df_unemployed2['State'].isin(states)]

#combining crime datasets
df_crime2013['Year'] = 2013
df_crime2014['Year'] = 2014
df_crime2015['Year'] = 2015
df_crime2016['Year'] = 2016
df_crime2017['Year'] = 2017
df_crime2018['Year'] = 2018
df_crime2019['Year'] = 2019

df_crime2015a = df_crime2015[["State","Area","Population","Violent\ncrime1","Property \ncrime","Year","Unnamed: 2"]]
df_crime2015a=df_crime2015a.rename(columns={"Violent\ncrime1": "Violent Crime", "Property \ncrime": "Property Crime"})
df_crime2016a = df_crime2016[["State","Area","Population","Violent\ncrime1","Property \ncrime","Year","Unnamed: 2"]]
df_crime2016a=df_crime2016a.rename(columns={"Violent\ncrime1": "Violent Crime", "Property \ncrime": "Property Crime"})
df_crime2017a = df_crime2017[["State","Area","Population","Violent\ncrime1","Property \ncrime","Year","Unnamed: 2"]]
df_crime2017a=df_crime2017a.rename(columns={"Violent\ncrime1": "Violent Crime", "Property \ncrime": "Property Crime"})
df_crime2018a = df_crime2018[["State","Area","Population","Violent crime1","Property \ncrime","Year","Unnamed: 2"]]
df_crime2018a=df_crime2018a.rename(columns={"Violent crime1": "Violent Crime", "Property \ncrime": "Property Crime"})
df_crime2019a = df_crime2019[["State","Area","Population","Violent \ncrime1","Property \ncrime","Year","Unnamed: 2"]]
df_crime2019a=df_crime2019a.rename(columns={"Violent \ncrime1": "Violent Crime", "Property \ncrime": "Property Crime"})

df_crimea = pd.concat([df_crime2013,df_crime2014,df_crime2015a,df_crime2016a,df_crime2017a, df_crime2018a, df_crime2019a], ignore_index=True)

# Forward fill state names since they only appear once per block
df_crimea['State'] = df_crimea['State'].ffill()


# Keep only rows where Area == State Total
df_crimerates = df_crimea[df_crimea['Unnamed: 2'] == "Rate per 100,000 inhabitants"].copy()
df_population = df_crimea[df_crimea["Area"]== "State Total"].copy()

df_crimerates['State'] = df_crimerates['State'].str.replace(r'\d+$', '', regex=True)  # remove trailing digits

df_population['State'] = df_population['State'].str.replace(r'\d+$', '', regex=True)  # remove trailing digits

df_population = df_population[["State","Year","Population"]]
df_crimerates = df_crimerates[["State","Year","Violent Crime","Property Crime"]]

df_crimetotals = df_population.merge(df_crimerates, on=["State","Year"], how="inner")

# Reset index
df_crimetotals = df_crimetotals.reset_index(drop=True)

#remapping crime dataset
state_mapping2 = {'ALABAMA': 'Alabama', 'ALASKA': 'Alaska', 'ARIZONA': 'Arizona', 'ARKANSAS': 'Arkansas', 'CALIFORNIA': 'California', 'COLORADO': 'Colorado', 'CONNECTICUT': 'Connecticut', 'DELAWARE': 'Delaware', 'FLORIDA': 'Florida', 'GEORGIA': 'Georgia', 'HAWAII': 'Hawaii', 'IDAHO': 'Idaho', 'ILLINOIS': 'Illinois', 'INDIANA': 'Indiana', 'IOWA': 'Iowa', 'KANSAS': 'Kansas', 'KENTUCKY': 'Kentucky', 'LOUISIANA': 'Louisiana', 'MAINE': 'Maine', 'MARYLAND': 'Maryland', 'MASSACHUSETTS': 'Massachusetts', 'MICHIGAN': 'Michigan', 'MINNESOTA': 'Minnesota', 'MISSISSIPPI': 'Mississippi', 'MISSOURI': 'Missouri', 'MONTANA': 'Montana', 'NEBRASKA': 'Nebraska', 'NEVADA': 'Nevada', 'NEW HAMPSHIRE': 'New Hampshire', 'NEW JERSEY': 'New Jersey', 'NEW MEXICO': 'New Mexico', 'NEW YORK': 'New York', 'NORTH CAROLINA': 'North Carolina', 'NORTH DAKOTA': 'North Dakota', 'OHIO': 'Ohio', 'OKLAHOMA': 'Oklahoma', 'OREGON': 'Oregon', 'PENNSYLVANIA': 'Pennsylvania', 'RHODE ISLAND': 'Rhode Island', 'SOUTH CAROLINA': 'South Carolina', 'SOUTH DAKOTA': 'South Dakota', 'TENNESSEE': 'Tennessee', 'TEXAS': 'Texas', 'UTAH': 'Utah', 'VERMONT': 'Vermont', 'VIRGINIA': 'Virginia', 'WASHINGTON': 'Washington', 'WEST VIRGINIA': 'West Virginia', 'WISCONSIN': 'Wisconsin', 'WYOMING': 'Wyoming' }
df_crimetotals["State"] = df_crimetotals['State'].map(state_mapping2)

#college enrollment datasets scrapped in the 2011-2019 version
df_college2013["Year"] = 2013
df_college2014["Year"] = 2014
df_college2015["Year"] = 2015
df_college2016["Year"] = 2016
df_college2017["Year"] = 2017
df_college2018["Year"] = 2018
df_college2019["Year"] = 2019
df_collegea = pd.concat([df_college2013,df_college2014,df_college2015,df_college2016,df_college2017,df_college2018,df_college2019])
df_collegea = df_collegea.rename(columns={"Total": "Total College Enrollment"})
df_collegeb = df_collegea[["State","Total College Enrollment","Year"]]
df_collegeb['State'] = df_collegeb['State'].str.replace(".", '').str.strip()
df_collegefinal = df_collegeb[df_collegeb['State'].isin(states)]

#death rate is per 1000, years taken care of
df_infantmort = df_infantmort.rename(columns = {"Death Rate": "Infant Mortality Rate","Year of Death" : "Year"})
df_infantmortfinal = df_infantmort[["State","Year","Infant Mortality Rate"]]

#poverty keeping 2013-2019
df_poverty = df_poverty[df_poverty['Year'] >= 2013]
df_poverty = df_poverty[df_poverty['Year'] <= 2019]
df_povertya = df_poverty.rename(columns = {"Name": "State"})
df_povertyb = df_povertya[df_povertya['State'].isin(states)]
df_povertyfinal = df_povertyb[["Year","State","Percent in Poverty"]]

#editing health insurance

df_insur2013["Year"] = 2013
df_insur2014["Year"] = 2014
df_insur2015["Year"] = 2015
df_insur2016["Year"] = 2016
df_insur2017["Year"] = 2017
df_insur2018["Year"] = 2018
df_insur2019["Year"] = 2019

df_insura = pd.concat([df_insur2013,df_insur2014,df_insur2015,df_insur2016,df_insur2017,df_insur2018,df_insur2019],ignore_index=True)
df_insura = df_insura.rename(columns = {"Location" : "State"})
df_insurb = df_insura[df_insura['State'].isin(states)]
df_insurfinal = df_insurb[["State","Year","Uninsured"]]

#keeping certain columns on gov spending
df_gova = df_govspending[["State","Year","(E001) Total Expenditure","(E024) Total Educ-Direct Exp","(E012) Total Salaries & Wages (Z00)", "(E058) Total Hospital-Dir Exp","(E074) Hous & Com-Direct Exp","(E077) Libraries-Direct Exp","(E087) Police Prot-Direct Exp","(E090) Public Welf-Direct Exp"]]
df_govfinal = df_gova.sort_values(by='Year')
df_govfinal['Year'] = df_govfinal['Year'].astype(int)

df_highgradrate['State'] = df_highgradrate['State'].str.replace(".", '').str.strip()
df_highgradrate = df_highgradrate[df_highgradrate['Year'] >= 2013]
df_highgradrate = df_highgradrate[df_highgradrate['Year'] <= 2019]
def check_nan_rows(df):
    """
    Checks the entire DataFrame for rows with NaN values.

    Args:
        df (pd.DataFrame): The DataFrame to check.

    Returns:
        pd.DataFrame: A DataFrame with index of rows containing NaNs
                      and the columns that are NaN in each row.
    """
    nan_info = []
    for idx, row in df.iterrows():
        nan_cols = row[row.isna()].index.tolist()
        if nan_cols:  # if the row has any NaNs
            nan_info.append({'row_index': idx, 'nan_columns': nan_cols})

    return pd.DataFrame(nan_info)
df_act.head()
print(df_collegefinal.shape)
# Out:
# (350, 3)
# /tmp/ipykernel_275/3581619357.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unemployed2["Percent (%) of Labor Force Unemployed in State/Area"] = pd.to_numeric(
# /tmp/ipykernel_275/3581619357.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_collegeb['State'] = df_collegeb['State'].str.replace(".", '').str.strip()

# %%
#@title Data Merges

#merging health and SAT
df_hs = df_sat.merge(df_healthf, on=["State","Year"])

df_uhs = df_hs.merge(df_unemployed2, on=["State","Year"]) #merge with unemployment

df_cuhs = df_uhs.merge(df_crimetotals, on=["State","Year"]) #merge with crime

df_ccuhs = df_cuhs.merge(df_collegefinal, on=["State","Year"]) #merge with college enrollment

df_iccuhs = df_ccuhs.merge(df_infantmortfinal,on=["State","Year"]) #merge with infant mortality

df_piccuhs = df_iccuhs.merge(df_povertyfinal, on=["State","Year"]) #merge with poverty

df_ipiccuhs = df_piccuhs.merge(df_insurfinal,on=["State","Year"]) #merge with health insurance

df_hipiccuhs = df_ipiccuhs.merge(df_highgradrate,on=["State","Year"]) #merge with high school grad rate

df_ghipiccuhs = df_hipiccuhs.merge(df_govfinal, on=["State","Year"]) #merge with govspending

df_aghipiccuhs = df_ghipiccuhs.merge(df_act,on=["State","Year"]) #merge with act

list(df_aghipiccuhs.columns)
# Out:
# ['State',
#  'Year',
#  'Participation',
#  'Evidence-Based Reading and Writing',
#  'Math',
#  'Total',
#  'RATIO',
#  'Percent of Labor Force Unemployed in State',
#  'Population',
#  'Violent Crime',
#  'Property Crime',
#  'Total College Enrollment',
#  'Infant Mortality Rate',
#  'Percent in Poverty',
#  'Uninsured',
#  'High School Graduation Rate',
#  '(E001) Total Expenditure',
#  '(E024) Total Educ-Direct Exp',
#  '(E012) Total Salaries & Wages (Z00)',
#  '(E058) Total Hospital-Dir Exp',
#  '(E074) Hous & Com-Direct Exp',
#  '(E077) Libraries-Direct Exp',
#  '(E087) Police Prot-Direct Exp',
#  '(E090) Public Welf-Direct Exp',
#  'Participation ACT',
#  'Composite']

# %%
import numpy as np

df_final = df_aghipiccuhs.copy()


df_final["State"].unique()
df_final["Total"] = df_final["Evidence-Based Reading and Writing"] + df_final["Math"]
df_final["Composite"] = df_final["Composite"].apply(pd.to_numeric,errors = 'coerce')
bins = [590, 620, 650, 690, 730, 780, 830, 880, 920, 960,
    990, 1030, 1060, 1100, 1130, 1160, 1200, 1230, 1260,
    1300, 1330, 1360, 1390, 1420, 1450, 1490, 1530, 1570, 1601]

act_scores = list(range(9, 37))

df_final["SAT_to_ACT"] = pd.cut(df_final["Total"], bins=bins,
    labels=act_scores,
    right=False).astype(float)

df_final['max_participation'] = df_final[['Participation', 'Participation ACT']].max(axis=1)

df_final['Score'] = np.where(df_final['Participation'] == df_final["max_participation"], df_final['SAT_to_ACT'], df_final["Composite"])


df_final["Score"] = (df_final["Score"] - df_final["Score"].min()) / (df_final["Score"].max() - df_final["Score"].min())

print(df_final.shape)
# Out:
# (350, 29)

# %%
 #@title Normalizing Variables

#final normalized set is called df_norm
df_norm=df_final.copy()

expend_cols=['(E001) Total Expenditure','(E012) Total Salaries & Wages (Z00)',"(E024) Total Educ-Direct Exp",'(E058) Total Hospital-Dir Exp','(E074) Hous & Com-Direct Exp', '(E077) Libraries-Direct Exp', '(E087) Police Prot-Direct Exp', '(E090) Public Welf-Direct Exp']


for col in expend_cols:
  df_norm[col] = df_norm[col].str.replace('$', '').astype(float)



fix_cols=["Infant Mortality Rate","High School Graduation Rate","Violent Crime","Property Crime"]
df_norm[fix_cols] = df_norm[fix_cols].apply(
    pd.to_numeric, errors="coerce"
)

numeric_cols=[
    "Total College Enrollment", "High School Graduation Rate", "Uninsured","Percent in Poverty","Infant Mortality Rate", "RATIO", "Percent of Labor Force Unemployed in State", "Violent Crime", "Property Crime",
]



df_norm[numeric_cols]=(df_norm[numeric_cols]-df_norm[numeric_cols].min())/(df_norm[numeric_cols].max()-df_norm[numeric_cols].min())

df_norm["Education Index"]=0.65*df_norm["Score"] + 0.2*df_norm["High School Graduation Rate"] + 0.15*df_norm["Total College Enrollment"]

df_norm["Health Index"]=0.55*df_norm["RATIO"] + 0.35*(1-df_norm["Infant Mortality Rate"]) + 0.2*(1-df_norm["Uninsured"])

df_norm["Social Index"]= 1- (0.35*df_norm["Violent Crime"] + 0.1*df_norm["Property Crime"] + 0.2*df_norm["Percent of Labor Force Unemployed in State"] + 0.35*df_norm["Percent in Poverty"])

df_norm["Index"] = df_norm[["Social Index","Health Index","Education Index"]].mean(axis=1)

# df_norm["Index"] = (df_norm["Social Index"]*df_norm["Health Index"]*df_norm["Education Index"])**(1/3)

df_norm[["State", "Year", "(E012) Total Salaries & Wages (Z00)"]]\
    .sort_values("(E012) Total Salaries & Wages (Z00)", ascending=False)\
    .head(70)
# Out:
#           State    Year  (E012) Total Salaries & Wages (Z00)
# 1        Alaska  2013.0                               3015.0
# 51       Alaska  2014.0                               2971.0
# 101      Alaska  2015.0                               2901.0
# 151      Alaska  2016.0                               2819.0
# 201      Alaska  2017.0                               2772.0
# ..          ...     ...                                  ...
# 79   New Jersey  2014.0                               1394.0
# 293        Utah  2018.0                               1391.0
# 299     Wyoming  2018.0                               1383.0
# 129  New Jersey  2015.0                               1382.0
# 236      Oregon  2017.0                               1367.0
#
# [70 rows x 3 columns]

# %%
#@title Training & Testing (gov spending v1)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# list_expenditures = ["(E001) Total Expenditure","(E012) Total Salaries & Wages (Z00)", "(E024) Total Educ-Direct Exp",
#                    "(E058) Total Hospital-Dir Exp","(E074) Hous & Com-Direct Exp",
#                    "(E077) Libraries-Direct Exp", "(E087) Police Prot-Direct Exp",
#                    "(E090) Public Welf-Direct Exp"]


list_expenditures = ["(E012) Total Salaries & Wages (Z00)","(E024) Total Educ-Direct Exp", "(E077) Libraries-Direct Exp",
                    "(E058) Total Hospital-Dir Exp","(E074) Hous & Com-Direct Exp",
                    "(E087) Police Prot-Direct Exp",
                    "(E090) Public Welf-Direct Exp"]

list_years = [2013,2014,2015,2016,2017]
list2_years = [2018,2019]


df_norm_train = df_norm[df_norm["Year"].isin(list_years)]
df_norm_test = df_norm[df_norm["Year"].isin(list2_years)]



X_train = df_norm_train[list_expenditures]
y_train = df_norm_train["Index"]

X_test = df_norm_test[list_expenditures]
y_test = df_norm_test["Index"]

baseline_model = LinearRegression()
baseline_model.fit(X_train, y_train)

y_predict = baseline_model.predict(X_test)
mse = mean_squared_error(y_test, y_predict)
r2 = r2_score(y_test,y_predict)

state_list = df_norm_test["State"]
state_list= np.array(state_list, dtype=np.str_ )


error_list = y_test-y_predict
df_error_state = pd.DataFrame({ 'Error': error_list, 'State': state_list})


df_error_state = df_error_state.groupby(['State']).mean().reset_index()
df_error_state['Error'] = df_error_state['Error']*df_error_state['Error']


mse_percent = mse*100/y_train.mean()
print(mse_percent)
print("r2", r2)

series_prediction = pd.Series(y_predict)
plt.scatter(series_prediction, y_test)

print(baseline_model.coef_)

df_error_state.plot.bar(x='State', y='Error', title='Error by State')


print(df_error_state.sort_values(by="Error", ascending=False).head(10))
len(X_train)
#y_test.plot()
#y_predict.plot()
#print(type(y_test))
#type(y_predict)
from scipy.stats import pearsonr

# Calculate Pearson correlation (r)
corr, _ = pearsonr(y_test, y_predict)

print(f"Pearson Correlation (r): {corr:.4f}")
print(f"r-squared (r^2): {corr**2:.4f}") # This is the "always positive" version
print(f"Actual Sklearn R2 Score: {r2:.4f}") # This is your original negative value
# Out:
# 1.9016466260740676
# r2 -0.11171107760083299
# [ 1.00117633e-04 -1.01529850e-06 -4.91490020e-03 -7.77054619e-06
#   1.02790512e-04 -9.10153210e-05 -2.44454135e-05]
#             State     Error
# 20  Massachusetts  0.045628
# 44        Vermont  0.036281
# 43           Utah  0.029445
# 28  New Hampshire  0.029376
# 22      Minnesota  0.029363
# 30     New Mexico  0.028615
# 45       Virginia  0.026476
# 29     New Jersey  0.024869
# 14           Iowa  0.022184
# 31       New York  0.021107
# Pearson Correlation (r): 0.3382
# r-squared (r^2): 0.1144
# Actual Sklearn R2 Score: -0.1117

# %%
residuals = y_test - y_predict

plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_predict, y=residuals, alpha=0.7)

plt.axhline(y=0, color='red', linestyle='--')

plt.xlabel('Predicted Index (Model Predictions)')
plt.ylabel('Residuals')
plt.title('Residual Plot: Gov Spending (Test Data)')
plt.grid(True, linestyle=':', alpha=0.6)

plt.show()

# %%
#@title Nerual Network
from sklearn.neural_network import MLPRegressor

mlp_model = MLPRegressor(hidden_layer_sizes=(5,5), activation='relu', solver='adam', max_iter=100, random_state=42, learning_rate_init=0.01)


mlp_model.fit(X_train, y_train)


y1_predict = mlp_model.predict(X_test)
mlp_mse = mean_squared_error(y_test, y1_predict)
mlp_mse_percent = mlp_mse*100/y_train.mean()

mlp_r2 = r2_score(y_test, y1_predict)

mlp_series_prediction = pd.Series(y1_predict)
plt.scatter(mlp_series_prediction, y_test)
print(mlp_mse_percent)
print(mlp_r2)
# Out:
# 45.875009641038325
# -25.81873472374615
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
residuals = y_test - y1_predict

plt.figure(figsize=(10, 6))
sns.scatterplot(x=y1_predict, y=residuals, alpha=0.7)

plt.axhline(y=0, color='red', linestyle='--')

plt.xlabel('Predicted Index (Model Predictions)')
plt.ylabel('Residuals')
plt.title('Residual Plot: Gov Spending (Test Data)')
plt.grid(True, linestyle=':', alpha=0.6)

plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor


regressor_model = RandomForestRegressor(n_estimators=100,random_state=42, max_depth=10, min_samples_split=5, min_samples_leaf=2, n_jobs=-1)
regressor_model.fit(X_train,y_train)
y2_predict = regressor_model.predict(X_test)
rf_mse = mean_squared_error(y_test,y2_predict)
rf_mse_percent = rf_mse*100/y_train.mean()


rf_series_prediction = pd.Series(y2_predict)
plt.scatter(rf_series_prediction, y_test)

rf_r2 = r2_score(y_test,y2_predict)
print(rf_mse_percent)
print(rf_r2)
print(y_test)

print(regressor_model.feature_importances_)
from scipy.stats import pearsonr

# Calculate Pearson correlation (r)
corr, _ = pearsonr(y_test, y2_predict)

print(f"Pearson Correlation (r): {corr:.4f}")
print(f"r-squared (r^2): {corr**2:.4f}") # This is the "always positive" version
print(f"Actual Sklearn R2 Score: {r2:.4f}") # This is your original negative value

plt.xlabel('Actual Index')
plt.ylabel('Predicted Index')
plt.title('Predicted vs. Actual Index: Random Forest Regressor')

# state_list = df_norm_test["State"]
# state_list= np.array(state_list, dtype=np.str_ )


# error_list = y_test-y2_predict
# df_error_state = pd.DataFrame({ 'Error': error_list, 'State': state_list})


# df_error_state = df_error_state.groupby(['State']).mean().reset_index()
# df_error_state['Error'] = df_error_state['Error']*df_error_state['Error']


# mse_percent = mse*100/y_train.mean()
# print(mse_percent)
# print("r2", r2)

# series_prediction = pd.Series(y2_predict)
# plt.scatter(series_prediction, y_test)

# print(baseline_model.coef_)

# df_error_state.plot.bar(x='State', y='Error', title='Error by State')


# print(df_error_state.sort_values(by="Error", ascending=False).head(10))
# Out:
# 0.8270102966932633
# 0.5165261013704012
# 250    0.452217
# 251    0.535978
# 252    0.484776
# 253    0.453591
# 254    0.644175
#          ...
# 345    0.701285
# 346    0.645755
# 347    0.442373
# 348    0.633494
# 349    0.562809
# Name: Index, Length: 100, dtype: float64
# [0.26588822 0.11755261 0.05416308 0.17327935 0.12274098 0.11425549
#  0.15212029]
# Pearson Correlation (r): 0.8138
# r-squared (r^2): 0.6622
# Actual Sklearn R2 Score: -0.1117
# Text(0.5, 1.0, 'Predicted vs. Actual Index: Random Forest Regressor')

# %%
residuals = y_test - y2_predict

plt.figure(figsize=(10, 6))
sns.scatterplot(x=y2_predict, y=residuals, alpha=0.7)

plt.axhline(y=0, color='red', linestyle='--')

plt.xlabel('Predicted Index (Model Predictions)')
plt.ylabel('Residuals')
plt.title('Residual Plot: Gov Spending (Test Data)')
plt.grid(True, linestyle=':', alpha=0.6)

plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

decision_model = DecisionTreeRegressor(max_depth=5,random_state=42)
decision_model.fit(X_train,y_train)
y3_predict=decision_model.predict(X_test)
dt_mse= mean_squared_error(y_test,y3_predict)
dt_mse_percent = dt_mse*100/y_train.mean()

dt_r2 = r2_score(y_test, y3_predict)

dt_prediction = pd.Series(y3_predict)
plt.scatter(dt_prediction, y_test)
print(dt_mse_percent)
print(dt_r2)

print(decision_model.feature_importances_)
# Out:
# 2.055725663873343
# -0.20178636856125798
# [0.2359894  0.0623877  0.05226933 0.12175599 0.20972196 0.18332736
#  0.13454826]

# %%
# @title Map(s)
# !pip install plotly-express

import plotly.express as px

state_map1 = {
    "Alabama": "AL", "Alaska": "AK", "Arizona": "AZ", "Arkansas": "AR",
    "California": "CA", "Colorado": "CO", "Connecticut": "CT", "Delaware": "DE",
    "Florida": "FL", "Georgia": "GA", "Hawaii": "HI", "Idaho": "ID",
    "Illinois": "IL", "Indiana": "IN", "Iowa": "IA", "Kansas": "KS",
    "Kentucky": "KY", "Louisiana": "LA", "Maine": "ME", "Maryland": "MD",
    "Massachusetts": "MA", "Michigan": "MI", "Minnesota": "MN", "Mississippi": "MS",
    "Missouri": "MO", "Montana": "MT", "Nebraska": "NE", "Nevada": "NV",
    "New Hampshire": "NH", "New Jersey": "NJ", "New Mexico": "NM",
    "New York": "NY", "North Carolina": "NC", "North Dakota": "ND",
    "Ohio": "OH", "Oklahoma": "OK", "Oregon": "OR", "Pennsylvania": "PA",
    "Rhode Island": "RI", "South Carolina": "SC", "South Dakota": "SD",
    "Tennessee": "TN", "Texas": "TX", "Utah": "UT", "Vermont": "VT",
    "Virginia": "VA", "Washington": "WA", "West Virginia": "WV",
    "Wisconsin": "WI", "Wyoming": "WY"
}
df_norm["abbrev_states"]=df_norm["State"].map(state_map1)

df_norm["Index"] = pd.to_numeric(df_norm["Index"])
df_norm["Social Index"] = pd.to_numeric(df_norm["Social Index"])
df_norm["Health Index"] = pd.to_numeric(df_norm["Health Index"])
df_norm["Education Index"] = pd.to_numeric(df_norm["Education Index"])

fig = px.choropleth(df_norm,
                    locations='abbrev_states', locationmode="USA-states",
                    scope="usa", color='Index',
                    color_continuous_scale="sunset",
animation_frame='Year'
                    )

fig.update_layout(
      title_text = 'Index by State',
      title_font_family="Times New Roman",
      title_font_size = 22,
      title_font_color="black",
      title_x=0.45,
         )


fig1 = px.choropleth(df_norm,
                    locations='abbrev_states',
                    locationmode="USA-states",
                    scope="usa",
                    color='Social Index',
                    color_continuous_scale="sunset",
animation_frame='Year'
                    )

fig1.update_layout(
      title_text = 'Social Index by State',
      title_font_family="Times New Roman",
      title_font_size = 22,
      title_font_color="black",
      title_x=0.45,
         )

fig2 = px.choropleth(df_norm,
                    locations='abbrev_states',
                    locationmode="USA-states",
                    scope="usa",
                    color='Health Index',
                    color_continuous_scale="sunset",
animation_frame='Year'
                    )

fig2.update_layout(
      title_text = 'Health Index by State',
      title_font_family="Times New Roman",
      title_font_size = 22,
      title_font_color="black",
      title_x=0.45,
         )


fig3 = px.choropleth(df_norm,
                    locations='abbrev_states',
                    locationmode="USA-states",
                    scope="usa",
                    color='Education Index',
                    color_continuous_scale="sunset",
animation_frame='Year'
                    )

fig3.update_layout(
      title_text = 'Education Index by State',
      title_font_family="Times New Roman",
      title_font_size = 22,
      title_font_color="black",
      title_x=0.45,
         )


fig.show()
fig1.show()
fig2.show()
fig3.show()
df_norm.head()
# Filter for Year 2014
edu_2014 = df_norm[df_norm['Year'] == 2016][['State', 'Education Index']]

# Optionally, sort by state
edu_2014 = edu_2014.sort_values('State').reset_index(drop=True)

print(edu_2014)
# Out:
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
states = ["California", "Michigan",'Massachusetts']
years = [2014, 2015, 2016]

columns_needed = [
    "State",
    "Year",
    "Total",              # or "Total" if that's your SAT total column
    "Composite",
    "Participation",
    "Participation ACT",

    "Total College Enrollment", "High School Graduation Rate","Score"
]

subset = df_final[
    (df_final["State"].isin(states)) &
    (df_final["Year"].isin(years))
][columns_needed]

print(subset)
# Out:
#              State    Year   Total  Composite  Participation  \
# 54      California  2014.0  1007.0       22.3           60.3
# 70   Massachusetts  2014.0  1043.5       24.3           84.1
# 71        Michigan  2014.0  1197.0       20.1            3.8
# 104     California  2015.0   999.0       22.5           60.0
# 120  Massachusetts  2015.0  1040.5       24.4           86.0
# 121       Michigan  2015.0  1198.5       20.1            4.0
# 154     California  2016.0   988.0       22.6           24.0
# 170  Massachusetts  2016.0  1041.5       24.8           84.0
# 171       Michigan  2016.0  1195.5       20.3          100.0
#
#      Participation ACT  Total College Enrollment High School Graduation Rate  \
# 54                29.0                 46.296886                          81
# 70                23.0                 52.127394                        86.1
# 71               100.0                 44.921750                        78.6
# ...

# %%
from sklearn.feature_selection import f_regression
from sklearn import datasets


X= df_norm[list_expenditures]
y=df_norm["Index"]
#X,y = datasets.load_iris(return_X_y=True)
f_scores,p_values = f_regression(X,y)
print("P-values for each feature: ")
print(p_values)

results = pd.DataFrame({
    "Feature": X.columns,
    "F_score": f_scores,
    "p_value": p_values
}).sort_values(by="F_score", ascending=False)

print(results)
# Out:
# P-values for each feature:
# [1.32729405e-04 2.53022666e-03 2.36826103e-01 1.87591375e-01
#  3.67422154e-03 3.69321812e-02 5.30309587e-01]
#                                Feature    F_score   p_value
# 0  (E012) Total Salaries & Wages (Z00)  14.935151  0.000133
# 1         (E024) Total Educ-Direct Exp   9.252553  0.002530
# 4         (E074) Hous & Com-Direct Exp   8.553729  0.003674
# 5        (E087) Police Prot-Direct Exp   4.387214  0.036932
# 3        (E058) Total Hospital-Dir Exp   1.743281  0.187591
# 2          (E077) Libraries-Direct Exp   1.404225  0.236826
# 6        (E090) Public Welf-Direct Exp   0.394588  0.530310

# %%
# @title Extra

plt.scatter(df_norm["(E087) Police Prot-Direct Exp"], df_norm["Violent Crime"])

# %%
plt.scatter(df_norm["(E024) Total Educ-Direct Exp"], df_norm["Education Index"])

# %%
# @title

path = kagglehub.dataset_download("adamschroeder/homelessness")

print("Path to dataset files:", path)


for item in os.listdir(path):
  print(item)

df_homeless = pd.read_csv(path + "/2007-2016-Homelessnewss-USA.csv")

df_homeless.head()
# Out:
# ...
# 100%|██████████| 524k/524k [00:00<00:00, 677kB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/adamschroeder/homelessness/versions/5
# 2007-2016-Homelessnewss-USA.csv
# Population-by-state.csv
#        Year State CoC Number       CoC Name  \
# 0  1/1/2007    AK     AK-500  Anchorage CoC
# 1  1/1/2007    AK     AK-500  Anchorage CoC
# 2  1/1/2007    AK     AK-500  Anchorage CoC
# 3  1/1/2007    AK     AK-500  Anchorage CoC
# 4  1/1/2007    AK     AK-500  Anchorage CoC
#
#                                      Measures Count
# 0            Chronically Homeless Individuals   224
# 1                        Homeless Individuals   696
# 2                 Homeless People in Families   278
# 3  Sheltered Chronically Homeless Individuals   187
# 4                          Sheltered Homeless   842

# %%
#@title Training & Testing (offset one year expenditures)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


list_expenditures = ["(E001) Total Expenditure","(E012) Total Salaries & Wages (Z00)", "(E024) Total Educ-Direct Exp",
                    "(E058) Total Hospital-Dir Exp","(E074) Hous & Com-Direct Exp",
                    "(E077) Libraries-Direct Exp", "(E087) Police Prot-Direct Exp",
                    "(E090) Public Welf-Direct Exp"]


list_expenditures1 = ["(E012) Total Salaries & Wages (Z00)","(E024) Total Educ-Direct Exp", "(E077) Libraries-Direct Exp",
                    "(E058) Total Hospital-Dir Exp","(E074) Hous & Com-Direct Exp",
                    "(E087) Police Prot-Direct Exp",
                    "(E090) Public Welf-Direct Exp"]


df_norm = df_norm.drop(columns=list_expenditures)

df_govspending1=df_govspending.copy()
df_govspending1["Year"]=df_govspending["Year"]+1
df_norm = df_norm.merge(df_govspending1, on=["State","Year"], how="left")


expend_cols=['(E001) Total Expenditure','(E012) Total Salaries & Wages (Z00)',"(E024) Total Educ-Direct Exp",'(E058) Total Hospital-Dir Exp','(E074) Hous & Com-Direct Exp', '(E077) Libraries-Direct Exp', '(E087) Police Prot-Direct Exp', '(E090) Public Welf-Direct Exp']


for col in expend_cols:
  df_norm[col] = df_norm[col].str.replace('$', '').astype(float)


list_years = [2013,2014,2015,2016,2017]
list2_years = [2018,2019]


df_norm_train = df_norm[df_norm["Year"].isin(list_years)]
df_norm_test = df_norm[df_norm["Year"].isin(list2_years)]



X_train = df_norm_train[list_expenditures1]
y_train = df_norm_train["Index"]

X_test = df_norm_test[list_expenditures1]
y_test = df_norm_test["Index"]

baseline_model = LinearRegression()
baseline_model.fit(X_train, y_train)

y_predict = baseline_model.predict(X_test)
mse = mean_squared_error(y_test, y_predict)
r2 = r2_score(y_test, y_predict)

state_list = df_norm_test["State"]
state_list= np.array(state_list, dtype=np.str_ )


error_list = y_test-y_predict
df_error_state = pd.DataFrame({ 'Error': error_list, 'State': state_list})


df_error_state = df_error_state.groupby(['State']).mean().reset_index()
df_error_state['Error'] = df_error_state['Error']*df_error_state['Error']


mse_percent = mse*100/y_train.mean()
print(mse_percent)
print(r2)

series_prediction = pd.Series(y_predict)
plt.scatter(series_prediction, y_test)

print(baseline_model.coef_)

df_error_state.plot.bar(x='State', y='Error', title='Error by State')
# Out:
# 1.9863877559392313
# -0.16125111911422607
# [ 9.34184689e-05 -9.74096459e-06 -3.58616648e-03 -8.56057707e-06
#  -1.40059832e-04  2.27660334e-04 -2.19721632e-05]
# <Axes: title={'center': 'Error by State'}, xlabel='State'>

# %%
from sklearn.ensemble import RandomForestRegressor


regressor_model = RandomForestRegressor(n_estimators=100,random_state=42, max_depth=10, min_samples_split=5, min_samples_leaf=2, n_jobs=-1)
regressor_model.fit(X_train,y_train)
y2_predict = regressor_model.predict(X_test)
rf_mse = mean_squared_error(y_test,y2_predict)
rf_mse_percent = rf_mse*100/y_train.mean()


rf_series_prediction = pd.Series(y2_predict)
plt.scatter(rf_series_prediction, y_test)

rf_r2 = r2_score(y_test,y2_predict)
print("mse",rf_mse_percent)
print(rf_r2)
print(y_test)

regressor_model.feature_importances_
# Out:
# mse 0.9583516708208439
# 0.4397433497471984
# 250    0.452217
# 251    0.535978
# 252    0.484776
# 253    0.453591
# 254    0.644175
#          ...
# 345    0.701285
# 346    0.645755
# 347    0.442373
# 348    0.633494
# 349    0.562809
# Name: Index, Length: 100, dtype: float64
# array([0.2549887 , 0.10444852, 0.06472581, 0.20284964, 0.09381701,
#        0.10724617, 0.17192416])
